# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.utils import resample

# %% [markdown]
# # 1. --- 讀檔 ---

# %%
# 下載Porto Seguro's Safe Driver Prediction competition資料集
# !gdown --id '1d-Z2NnX9d59Eff-zUNaDlopB1mvHGAW' --output c_1_001.csv
# Out:
# Permission denied: https://drive.google.com/uc?id=1d-Z2NnX9d59Eff-zUNaDlopB1mvHGAW
# Maybe you need to change permission over 'Anyone with the link'?

# %%
# 讀c_1_001.csv
df = pd.read_csv("c_1_001.csv",  
                 names = [ 'ch1', 'ch2', 'ch3', 'ch4', 'ch5', 'ch6', 'ch7' ] )
# ch1 = 切削力(X軸)
# ch2 = 切削力(Y軸)
# ch3 = 切削力(Z軸)
# ch4 = 振動(X軸)
# ch5 = 振動(Y軸)
# ch6 = 振動(Z軸)
# ch7 = 聲發感測器測量 AE-RMS
# Out:
# Permission denied: https://drive.google.com/uc?id=1d-Z2NnX9d59Eff-zUNaDlopB1mvHGAW
# Maybe you need to change permission over 'Anyone with the link'?
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-9171a96dc550> in <module>()
#       4 # 讀c_1_001.csv
#       5 df = pd.read_csv("c_1_001.csv",
# ----> 6                  names = [ 'ch1', 'ch2', 'ch3', 'ch4', 'ch5', 'ch6', 'ch7' ] )
#       7 # ch1 = 切削力(X軸)
#       8 # ch2 = 切削力(Y軸)
#
# ...
