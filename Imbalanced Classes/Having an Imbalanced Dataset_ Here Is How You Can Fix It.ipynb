# %% [markdown]
# 參考網址: https://towardsdatascience.com/having-an-imbalanced-dataset-here-is-how-you-can-solve-it-1640568947eb

# %%
import pandas as pd
import numpy as np
from google.colab import files

# %%
uploaded = files.upload()
df = pd.read_csv('creditcard.csv',
                 names = [ 'Time', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8', 'v9' ] )
                          # 'Time', 為1個目標變數, 代表的是第二筆交易與資料集中的第一個交易之間經過的秒數。
                          # 'v1' ~ 'v9', 為input的特徵
df.head()

# %%
# 使用二元分類法
df['Time'] = [1 if b == '1' else '0' for b in df. Time]
df['Time'].value_counts()
